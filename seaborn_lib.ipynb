# %%
import seaborn as sns

# %%
df = sns.load_dataset("flights")

# %%
# flights name id dependent features
# Year , month , Passengers field is independent features
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.dtypes
# Out:
# year             int64
# month         category
# passengers       int64
# dtype: object

# %% [markdown]
# Correlation with Heatmap

# %%
df.corr()
# Out:
#                 year  passengers
# year        1.000000    0.921824
# passengers  0.921824    1.000000

# %%
# heatmap use for visulization
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Univariate Analysis

# %%
sns.jointplot(x='year',y='passengers',data=df,kind='hex')

# %%
sns.jointplot(x='year',y='passengers',data=df,kind='reg')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='month')

# %%
df['month'].value_counts()
# Out:
# Jan    12
# Feb    12
# Mar    12
# Apr    12
# May    12
# Jun    12
# Jul    12
# Aug    12
# Sep    12
# Oct    12
# Nov    12
# Dec    12
# Name: month, dtype: int64

# %%
sns.distplot(df['passengers'],kde = False , bins=10)
# Out:
# /home/bhavik/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='passengers'>

# %% [markdown]
# Count Plot

# %%
sns.countplot('month',data=df)
# Out:
# /home/bhavik/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='month', ylabel='count'>

# %%
sns.countplot(y='month',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='month'>

# %%
#in a Bar plot you need to specify value of x and y axis
sns.barplot(x='month',y='passengers',data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='passengers'>

# %% [markdown]
# Box Plot

# %%
sns.boxplot('month','passengers',data=df)
# Out:
# /home/bhavik/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='month', ylabel='passengers'>

# %%
# categorize Data (hue values are compared value)

sns.boxplot(x='year',y='passengers',hue='month',data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %% [markdown]
# Violin Plot

# %%
sns.violinplot(x='passengers',y='month',data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='passengers', ylabel='month'>

# %%
# iris dataset for practice all this
